# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %% [markdown]
# Part 1:
# Exploratory data analysis

# %%
data = datasets.load_wine()

data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %%
type(data.data), type(data.target)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
data.data.shape
# Out:
# (178, 13)

# %%
data.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
data.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
x = data.data
y = data.target

df = pd.DataFrame(x, columns = data.feature_names)
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
print(df.groupby(data.target).size())
# Out:
# 0    59
# 1    71
# 2    48
# dtype: int64

# %%
visual = pd.plotting.scatter_matrix(df, figsize= [10,10], c = y, s = 150)

# %%
data = datasets.load_wine()
x = data.data
y = data.target

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size= 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test, predictions)
# Out:
# 0.9166666666666666

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size= 0.2)
model.fit(X_train, Y_train)
predicitions = model.predict(X_test)
accuracy_score(Y_test, predictions)
# Out:
# 0.4722222222222222

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size= 0.2)
model.fit(X_train, Y_train)
predicitions = model.predict(X_test)
accuracy_score(Y_test, predictions)
# Out:
# 0.4166666666666667

# %%
# !pip install joblib

# %%
import joblib as jb

# %%
jb.dump(model, 'wine-decision-tree.joblib')
# Out:
# ['wine-decision-tree.joblib']

# %%
model = jb.load('wine-decision-tree.joblib')

# %%
from sklearn import tree

# %%
import pydotplus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35756\291121575.py in <module>
# ----> 1 import pydotplus
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
from IPython.display import Image

# %%
dot_data = tree.export_graphviz(model, out_file=None, feature_names=['sepal-length', 'sepal-width', 'petal-length', 'petal width'], label='all', rounded=True, filled=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35756\1032059904.py in <module>
# ----> 1 dot_data = tree.export_graphviz(model, out_file=None, feature_names=['sepal-length', 'sepal-width', 'petal-length', 'petal width'], label='all', rounded=True, filled=True)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     887             fontname=fontname,
#     888         )
# --> 889         exporter.export(decision_tree)
#     890
#     891         if return_string:
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_export.py in export(self, decision_tree)
#     450         if self.feature_names is not None:
# ...

# %%
graph = pydotplus.graph_from_dot_data(dot_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35756\1535750591.py in <module>
# ----> 1 graph = pydotplus.graph_from_dot_data(dot_data)
#
# NameError: name 'pydotplus' is not defined
